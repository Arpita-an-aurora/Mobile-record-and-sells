# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
def sort_data():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile)
    while True:
        n=int(input('Enter 1 to sort price\n Enter 2 to sort ratings\n Enter 3 to sort camera megapixel\n Enter 4 to sort display size\n Enter 5 to sort storage\n Enter 6 to sort ram\n Enter 7 to sort battery power\n enter 8 when you are done with the filter\n'))
        if n==1:
            print('filtered by Price')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_price=mobile.sort_values(by='PRICE')
                print('sorted by Price: low to high')
                print(sorted_data_by_price)
            elif l==2:
                sorted_data_by_price=mobile.sort_values(by='PRICE', ascending=False)
                print('sorted by Price: high to low')
                print(sorted_data_by_price)
        elif n==2:
            print('filtered by Ratings')
            l=int(input("1.  high to low\n 2. low to high\n "))
            if l==1:
                sorted_data_by_ratings=mobile.sort_values(by='RATINGS', ascending=False)
                print('sorted by ratings: high to low')
                print(sorted_data_by_ratings)
            elif l==2:
                sorted_data_by_ratings=mobile.sort_values(by='RATINGS')
                print('sorted by ratings: low to high')
                print(sorted_data_by_ratings)
        elif n==3:
            print('filtered by Camera Quality')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_camera=mobile.sort_values(by='CAMERA')
                print('sorted by Camera: low to high')
                print(sorted_data_by_camera)
            elif l==2:
                sorted_data_by_camera=mobile.sort_values(by='CAMERA', ascending=False)
                print('sorted by Camera: high to low')
                print(sorted_data_by_camera)
        elif n==4:
            print('filtered by Display Size')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_size=mobile.sort_values(by='DISPLAY SIZE')
                print('sorted by Display size: low to high')
                print(sorted_data_by_size)
            elif l==2:
                sorted_data_by_size=mobile.sort_values(by='DISPLAY SIZE', ascending=False)
                print('sorted by Display size: high to low')
                print(sorted_data_by_size)
        elif n==5:
            print('filtered by Storage')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_storage=mobile.sort_values(by='STORAGE')
                print('sorted by Storage: low to high')
                print(sorted_data_by_storage)
            elif l==2:
                sorted_data_by_storage=mobile.sort_values(by='STORAGE', ascending=False)
                print('sorted by Storage: high to low')
                print(sorted_data_by_storage)
        elif n==6:
            print('filtered by ram')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_ram=mobile.sort_values(by='RAM')
                print('sorted by RAM: low to high')
                print(sorted_data_by_ram)
            elif l==2:
                sorted_data_by_ram=mobile.sort_values(by='RAM', ascending=False)
                print('sorted by RAM: high to low')
                print(sorted_data_by_ram)
        elif n==7:
            print('filtered by battery')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_battery=mobile.sort_values(by='BATTERY')
                print('sorted by battery power: low to high')
                print(sorted_data_by_battery)
            elif l==2:
                sorted_data_by_battery=mobile.sort_values(by='BATTERY', ascending=False)
                print('sorted by battery power: high to low')
                print(sorted_data_by_battery)
        else:
            break
# Out:
#       BRAND     MODEL     REVIEW  RATINGS  PRICE  CAMERA DISPLAY  \
# 0  one plus  ce3 lite  excellent      4.5  22000     108    oled
# 1   samsung        n2       fair      4.0  26000      64     led
# 2  one plus  ce2 lite       good      3.0  29000      64     led
#
#    DISPLAY SIZE  STORAGE  RAM         OS    COLOUR  BATTERY   ORIGIN
# 0          12.5      256    8  oxygen os      grey     6000    india
# 1          11.8      128    6    android  lavender     5000  s korea
# 2          12.0      128    6      oxyos      lime     5004    china
# Enter 1 to sort price
#  Enter 2 to sort ratings
#  Enter 3 to sort camera megapixel
#  Enter 4 to sort display size
#  Enter 5 to sort storage
#  Enter 6 to sort ram
#  Enter 7 to sort battery power
#  enter 8 when you are done with the filter
# 8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
def filter_by_features():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile)
    print('FILTER BY FEATURES')
    while True:
        a=int(input("1. brand mp\n 2. model\n 3. review\n 4. camera mp\n 5. display\n 6. display size\n 7. storage\n 8. ram\n 9. os\n 10. color\n 11. battery power\n 12. origin\n 13. done"))
        if a==1:
            filtered_brand=input('enter brand to filter: 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print(filtered_data)
            else:
                print('Sorry. This brand is not available at this moment')
        elif a==2:
            filtered_model=input('enter model to filter: 1.')
            a=list(mobile['MODEL'])
            if filtered_model in a:
                filtered_data=mobile[mobile['MODEL']==filtered_model]
                print(filtered_data)
            else:
                print('Sorry. This model is not available at this moment')
        elif a==3:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('choose from review: ',filtered_data['REVIEW'])
                b=list(filtered_data['REVIEW'])
                filtered_review=input('enter review to show: ')
                if filtered_review in b:
                    final_filtered_data=filtered_data[filtered_data['REVIEW']==filtered_review]
                    print(final_filtered_data)
                else:
                    print('Sorry. The review panel doesnot include this')
            elif filtered_brand not in a:
                print('choose from review: ',mobile['REVIEW'])
                c=list(mobile['REVIEW'])
                filtered_review=input('enter review to show: ')
                if filtered_review in c:
                    filtered_data=mobile[mobile['REVIEW']==filtered_review]
                    print(filtered_data)
                else:
                    print('Sorry. The review panel doesnot include this')
        elif a==4:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available camera quality(mp) are:', filtered_data['CAMERA'])
                b=list(filtered_data['CAMERA'])
                filtered_camera=int(input('enter camera mp to filter: '))
                if filtered_camera in b:
                    final_filtered_data=filtered_data[filtered_data['CAMERA']==filtered_camera]
                    print(final_filtered_data)
                else:
                    print('Sorry. This quality camera is not available in this brand')
            elif filtered_brand not in a:
                print('available camera quality(mp) are: ',mobile['CAMERA'])
                filtered_camera=int(input('enter camera mp to filter: '))
                c=list(mobile['CAMERA'])
                if filtered_camera in c:
                    filtered_data=mobile[mobile['CAMERA']==filtered_camera]
                    print(filtered_data)
                else:
                    print('Sorry. This quality camera is not available')
        elif a==5:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available display type are:', filtered_data['DISPLAY'])
                filtered_display=input('enter display to filter: ')
                b=list(filtered_data['DISPLAY'])
                if filtered_display in b:
                    final_filtered_data=filtered_data[filtered_data['DISPLAY']==filtered_display]
                    print(final_filtered_data)
                else:
                    print('Sorry. This display type is not available for this brand')
            elif filtered_brand not in a:
                print('available display type are: ',mobile['DISPLAY'])
                filtered_display=input('enter display to filter: ')
                c=list(mobile['DISPLAY'])
                if filtered_display in c:
                    filtered_data=mobile[mobile['DISPLAY']==filtered_display]
                    print(filtered_data)
                else:
                    print('Sorry. This display type is not available')
        elif a==6:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available display_size are:', filtered_data['DISPLAY SIZE'])
                filtered_display_size=float(input('enter display_size to filter: '))
                b=list(filtered_data['DISPLAY SIZE'])
                if filtered_display_size in b:
                    final_filtered_data=filtered_data[filtered_data['DISPLAY SIZE']==filtered_display_size]
                    print(final_filtered_data)
                else:
                    print('Sorry. This display size is not available for this brand')
            elif filtered_brand not in a:
                print('available display_size are: ',mobile['DISPLAY SIZE'])
                filtered_display_size=float(input('enter display_size to filter: '))
                c=list(mobile['DISPLAY SIZE'])
                if filtered_display_size in c:
                    filtered_data=mobile[mobile['DISPLAY SIZE']==filtered_display_size]
                    print(filtered_data)
                else:
                    print('Sorry. This display size is not available')
        elif a==7:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available storage are:', filtered_data['STORAGE'])
                b=list(filtered_data['STORAGE'])
                filtered_storage=float(input('enter storage to filter: '))
                if filtered_storage in b:
                    final_filtered_data=filtered_data[filtered_data['STORAGE']==filtered_storage]
                    print(final_filtered_data)
                else:
                    print('Sorry. This storage is not available for this brand')
            elif filtered_brand not in a:
                print('available storage are: ',mobile['STORAGE'])
                filtered_storage=float(input('enter storage to filter: '))
                c=list(mobile['STORAGE'])
                if filtered_storage in c:
                    filtered_data=mobile[mobile['STORAGE']==filtered_storage]
                    print(filtered_data)
                else:
                    print('Sorry. This storage is not available')
        elif a==8:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available ram are:', filtered_data['RAM'])
                filtered_ram=float(input('enter storage to filter: '))
                b=list(filtered_data['RAM'])
                if filtered_ram in b:
                    final_filtered_data=filtered_data[filtered_data['RAM']==filtered_ram]
                    print(final_filtered_data)
                else:
                    print('Sorry. This ram is not available for this brand')
            elif filtered_brand not in a:
                print('available ram are: ',mobile['RAM'])
                filtered_ram=float(input('enter ram to filter: '))
                c=list(mobile['RAM'])
                if filtered_ram in c:
                    filtered_data=mobile[mobile['RAM']==filtered_ram]
                    print(filtered_data)
                else:
                    print('Sorry. This ram is not available')
        elif a==9:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available os are:', filtered_data['OS'])
                filtered_os=input('enter os to filter: ')
                b=list(filtered_data['OS'])
                if filtered_os in b:
                    final_filtered_data=filtered_data[filtered_data['OS']==filtered_os]
                    print(final_filtered_data)
                else:
                    print('Sorry. This os is not available for this brand')
            elif filtered_brand not in a:
                print('available os are: ',mobile['OS'])
                filtered_os=input('enter os to filter: ')
                c=list(mobile['OS'])
                if filtered_os in c:
                    filtered_data=mobile[mobile['OS']==filtered_os]
                    print(filtered_data)
                else:
                    print('Sorry. This storage is not available')
        elif a==10:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available color are:', filtered_data['COLOUR'])
                filtered_color=input('enter storage to filter: ')
                b=list(filtered_data['COLOUR'])
                if filtered_color in b:
                    final_filtered_data=filtered_data[filtered_data['COLOUR']==filtered_color]
                    print(final_filtered_data)
                else:
                    print('Sorry. This color is not available for this brand')
            elif filtered_brand not in a:
                print('available color are: ',mobile['COLOUR'])
                filtered_color=input('enter color to filter: ')
                c=list(mobile['COLOUR'])
                if filtered_color in c:
                    filtered_data=mobile[mobile['COLOUR']==filtered_color]
                    print(filtered_data)
                else:
                        print('Sorry. This color is not available')
        elif a==11:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a: 
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available battery power are:', filtered_data['BATTERY'])
                filtered_battery_power=int(input('enter battery power to filter: '))
                b=list(filtered_data['BATTERY'])
                if filtered_battery_power in b:
                    final_filtered_data=filtered_data[filtered_data['BATTERY']==filtered_battery_power]
                    print(final_filtered_data)
                else:
                    print('Sorry. This storage is not available for this brand')
            elif filtered_brand not in a:
                print('available battery power are: ',mobile['BATTERY'])
                filtered_battery_power=int(input('enter battery power to filter: '))
                c=list(mobile['BATTERY'])
                if filtered_battery_power in c:
                    filtered_data=mobile[mobile['BATTERY']==filtered_battery_power]
                    print(filtered_data)
                else:
                    print('Sorry. This battery power is not available')
        elif a==12:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available origin are:', filtered_data['ORIGIN'])
                filtered_origin=input('enter origin to filter: ')
                b=list(filtered_data['ORIGIN'])
                if filtered_origin in b:
                    final_filtered_data=filtered_data[filtered_data['ORIGIN']==filtered_origin]
                    print(final_filtered_data)
                else:
                    print('Sorry. No brand available of this country')
            elif filtered_brand not in a:
                print('available origin are: ',mobile['ORIGIN'])
                filtered_origin=input('enter origin to filter: ')
                c=list(mobile['ORIGIN'])
                if filtered_origin in c:
                    filtered_data=mobile[mobile['ORIGIN']==filtered_origin]
                    print(filtered_data)
                else:
                    print('Sorry. No brand available of this country')
        else:
            print('okay.Seems like you are done with your filters')
            break
filter_by_features()
# Out:
#          BRAND             MODEL     REVIEW  RATINGS   PRICE  CAMERA DISPLAY  \
# 0        apple          iphoneGS       good      4.5   12560       3     LCD
# 1        apple          iphoneXR  very good      4.5   41699      12     LCD
# 2        apple         iphone 6+       fair      4.5   18499       8     LCD
# 3        apple         iphone 11  very good      4.6  40,999      12     LCD
# 4        apple         iphone 12       good      4.6   53999      12    OLED
# 5        apple      iphone12 pro       good      4.1  109900      12    OLED
# 6        apple         iphone 13  very good      4.5   61999      12    OLED
# 7        apple          iphone14  very good      4.6   67999      12    OLED
# 8        apple  iphone14 pro max  very good      4.7  127999      48    OLED
# 9        apple        iphone 14+  very good      4.7   78999      12    OLED
# 10       apple          iphone X  very good      4.4   28999      12    OLED
# 11       apple         iphone SE       good      3.9    8490      12  Retina
# 12        benq                F3        bad      2.2   19998      13     LCD
# 13        benq                A3   very bad      1.3    5499       8     LCD
# 14  blackberry            evolve       fair      3.4   24990      13     LCD
# 15  blackberry            keyone       good      3.8   24399      12     LCD
# 16  blackberry            aurora       good      4.0   15699      13     LCD
# 17  blackberry              leap       fair      3.4   14999       8     LCD
# 18  blackberry                z3       good      4.0   19000       5     LCD
# 19     coolpad           cool 20  very good      4.6   20779      48     LCD
# 20     coolpad           cool 20  very good      4.5   20999      48     LCD
# 21     coolpad         legacy 5G       good      4.2   27990      48     LCD
# 22     coolpad          cool 10A       good      4.0    7990      13     LCD
# 23     coolpad        cool3 plus       fair      3.0    7999      13     LCD
# 24     coolpad        cool3 plus       fair      3.0    7999      13     LCD
# 25     coolpad        note3 lite       good      3.9    4090      13     LCD
# 26        dell           venue 8       good      4.0   16799       5    OLED
# 27        dell           venue 8       good      4.0   11999       5    OLED
# 28        dell    streak pro D43       fair      3.5   23862       8  AMOLED
# 29       eten       glofishxX610  excellent      5.0   19998       2     LCD
# 30       eten       glofishxV900  very good      4.7   21899       3     LCD
# 31   fairphone                 4       good      4.0   49990      48     LCD
# 32   fairphone                 4       fair      3.4   48181      48     LCD
# 33   fairphone                3+        bad      2.5   39999      48     LCD
# 34   fairphone                 3        bad      2.4   35447      12     LCD
# 35      google        pixel fold  very good      4.5  145690      48    OLED
# 36      google          pixel 7a  very good      4.6   43999      64    OLED
# 37      google           pixel 3       good      3.8   49999      12    OLED
# 38      google        pixel 2 xl       good      3.6   19990      12    OLED
# 39      google       pixel 4a 5G  very good      4.7   43990      16    OLED
# 40      google          pixel 6a  very good      4.2   28999      12    OLED
# 41      google       pixel 6 pro       good      3.9   44999      50    OLED
# 42      google       pixel 6 pro       good      3.9   44999      50    OLED
#
#     DISPLAY SIZE  STORAGE     RAM                            OS  \
# 0           3.50   32.000   8.000                      ios6.1.3
# 1           6.06   64.000   3.000                           ios
# 2           4.70   64.000   1.000                          ios8
# 3           6.10   64.000   4.000                         iod13
# 4           6.10   64.000   4.000                        ios 14
# 5           6.10  128.000   6.000                         ios14
# 6           6.10  128.000   4.000                         ios15
# 7           6.10  128.000   6.000                        ios 16
# 8           6.70  128.000   6.000                        ios 16
# 9           6.70  128.000   6.000                         ios16
# 10          5.80  256.000   3.000                         ios11
# 11          4.00   16.000   2.000                          ios9
# 12          4.50    4.000   1.000                    android4.2
# 13          4.50    4.000   1.000                    android4.1
# 14          5.99   64.000   4.000                    android8.1
# 15          4.50   64.000   3.000                    android8.1
# 16          5.50   32.000   4.000                     android 7
# 17          5.00   16.000   2.000                      os10.3.1
# 18          5.00    8.000   1.500                      os10.3.1
# 19          6.52   64.000   4.000                     android11
# 20          6.52  128.000   6.000                     android11
# 21          6.53   64.000   4.000                    android 10
# 22          6.52   64.000   2.000                     android11
# 23          5.71   16.000   2.000                      android9
# 24          5.71   32.000   3.000                      android9
# 25          5.00   16.000   3.000                    android5.1
# 26          8.00   16.000   2.000                  android4.2.2
# 27          8.00   32.000   2.000                  android4.2.2
# 28          4.30    8.000   1.000                    android2.3
# 29          2.80    0.064   0.064  microsoft windows mobile 6.1
# 30          2.80    0.128   0.128  microsoft windows mobile 6.1
# 31          6.30  256.000   8.000                    android 11
# 32          6.30  128.000   6.000                     android11
# 33          5.65   64.000   4.000                     android10
# 34          5.65   64.000   4.000                      android9
# 35          7.60  256.000  12.000                    android 13
# 36          6.10  128.000   8.000                    android 13
# 37          5.50   64.000   4.000                     android 9
# 38          6.00   64.000   4.000                     android 8
# 39          6.20  128.000   6.000                     android11
# 40          6.10  128.000   6.000                    android 12
# 41          6.70  128.000  12.000                    android 12
# 42          6.70  128.000  12.000                    android 12
#
#              COLOUR  BATTERY       ORIGIN
# 0             black     1400      Germany
# 1              blue     2942       Taiwan
# 2              grey     1810        India
# 3            purple     3110        India
# 4            purple     2815           US
# 5      Pacific blue     2815        Japan
# 6               Red     3240        India
# 7          midnight     3279        China
# 8       deep purple     4323        China
# 9         starlight     4325        China
# 10             grey     2716    Australia
# 11        rose gold     1624   Kazakhstan
# 12            white     2100   Bangladesh
# 13            black     2000   Bangladesh
# 14            black     4000           Uk
# 15           silver     3500           Uk
# 16            black     3000       Canada
# 17            black     2800        Spain
# 18            black     2500           Uk
# 19            white     4500        China
# 20   deep sea green     4500        China
# 21           silver     4000        China
# 22             blue     4000        China
# 23     cherry black     3000        China
# 24       ocean blue     3000        China
# 25      cocoa white     2500        China
# 26           black      4100           US
# 27            black     4100           US
# 28            black     1520        China
# 29            black     1530    Australia
# 30            black     1530    Australia
# 31            green     3905  Netherlands
# 32            green     3905  Netherlands
# 33            black     3040  Netherlands
# 34            black     3040  Netherlands
# 35        porcelain     4821           US
# 36             snow     4385           US
# 37         not pink     2915           US
# 38  black and white     3520           US
# 39            black     3885           US
# 40             sage     4410           US
# 41     cloudy white     5003           US
# 42     cloudy white     5003           US
# FILTER BY FEATURES
