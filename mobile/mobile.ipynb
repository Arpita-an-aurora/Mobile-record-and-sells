# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
def enter_data():
    enter_serial=None
    enter_brand=None
    enter_model=None
    enter_review=None
    enter_ratings=None
    enter_price=None
    camera=None
    display=None
    display_size=None
    storage=None
    ram=None
    os=None
    battery=None
    revenue1990=None
    revenue2000=None
    revenue2010=None
    revenue2020=None
    while True:
        for_features=int(input("Enter:\n 1.serial no. \n 2.for brand\n 3.for model\n 4.for review\n 5.for ratings\n 6.for price\n 7.for camera mp\n 8. for display\n 9. for display size\n 10. storage\n 11. Ram\n 12. os\n 13.battery power\n 14. annual revenue 1990\n 15. annual revenue 2000\n 16. annual revenue 2010\n 17. annual revenue 2020\n 18. exit\n"))
        mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
        if for_features==1:
            enter_serial=int(input('enter serial'))
        elif for_features==2:
            enter_brand=input("Enter brand: ")
        elif for_features==3:
            enter_model=input("Enter model")
        elif for_features==4:
            enter_review=input("Enter review (excellent; good; fair; poor; very poor):")
        elif for_features==5:
            enter_ratings=float(input("Enter ratings (1-5) "))
        elif for_features==6:
            enter_price=float(input("Enter price "))
        elif for_features==7:
            camera=int(input("Enter camera mp"))
        elif for_features==8:
            display=input("Enter  display ")
        elif for_features==9:
            display_size=float(input("Enter display size"))
        elif for_features==10:
            storage=float(input("Enter storage/rom: "))
        elif for_features==11:
            ram=float(input("Enter ram: "))
        elif for_features==12:
            os=input("Enter operating system:")
        elif for_features==13:
            battery=input("Enter battery power rating: ")
        elif for_features==14:
            revenue1990=input("Enter country of annual revenue 1990: ")
        elif for_features==15:
            revenue2000=input("Enter country of annual revenue 2000: ")
        elif for_features==16:
            revenue2021=input("Enter country of annual revenue 2010: ")
        elif for_features==17:
            revenue2020=input("Enter country of annual revenue 2020:")
        else:
            break
    mobile=mobile.append({'SR_NO':enter_serial,'BRAND':enter_brand,'MODEL':enter_model,'REVIEW':enter_review,'RATINGS':enter_ratings,'PRICE':enter_price, 'CAMERA':camera,'DISPLAY':display,'DISPLAY SIZE':display_size, 'STORAGE':storage, 'RAM':ram, 'OS':os, 'BATTERY':battery, 'ANNUAL REVENUE 1990': revenue1990, 'ANNUAL REVENUE 2000': revenue2000, 'ANNUAL REVENUE 2010': revenue2010, 'ANNUAL REVENUE 2020': revenue2020}, ignore_index=True)
    print(mobile)
    mobile.to_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv', index=False)
def new_record():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    #print(mobile)
    t=mobile.BRAND.count()
    m=mobile.columns
    nrec_values=[]
    for f in m:
        print('for',f,'\t')
        value=input('enter data: ')
        nrec_values.append(value)
    print(nrec_values)
    mobile.loc[t]=nrec_values
    print(mobile)
    mobile.to_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv',index=False)
def retrieve_one_specific_data():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile)
    n=int(input("Enter 1 to access a specific data using index numbers\n Enter 2 to access a specific data using index names"))
    if n==1:
        r=int(input('Enter row number: '))
        c=int(input('Enter column number: '))
        print(mobile.iat[r,c])
    elif n==2:
        a=mobile.columns
        b=list(mobile.index)
        print(a,': columns\n',b,':rows')
        r=input('enter row label')
        c=input('enter column label')
        print(mobile.at[r,c])        
def transpose():#to write in drop down as to inter change rows and column
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile.T)
def renaming_column():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    l=mobile.columns
    c=input('Enter column name you want to rename:')
    r=input("Enter new name of the provided column: ")
    mobile.rename(columns={c:r}, inplace=True)
    mobile.to_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv',index=False)
def select_a_column():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    n=int(input('enter 1 to select by name\n enter 2 to select by index'))
    if n==1:
        c=mobile.columns
        s=input('enter the column:')
        print(mobile.loc[:,s])
    elif n==2:
        s=int(input('enter the column index:'))
        print(mobile.loc[:,s])
def select_a_row():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    r=int(input('enter the first row index: '))
    print(mobile[r])
def select_a_part_of_data():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    r=int(input('enter row index'))
    rl=int(input('enter limiting row index: '))
    c=input('enter column label: ')
    cl=input('enter limiting column label: ')
    print(mobile.loc[r:rl,c:cl])
def head():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile.columns)
    c=input('enter the column based on which we will provide you topmost results: ')
    mobile.sort_values(by=c,ascending=False, inplace=True)
    h=int(input('enter the number of topmost results: ')) 
    print(mobile.head(h))
def tail():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile.columns)
    c=input('enter the column based on which we will provide you bottom most results: ')
    mobile.sort_values(by=c, ascending=False, inplace=True)
    t=int(input('enter the number of bottom most results: ')) 
    print(mobile.tail(t))
def delete_a_column():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile.columns)
    dc=input('enter column to be deleted: ')
    mobile.drop(dc, axis=1, inplace=True)
    mobile.to_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv',index=False)
def display():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile)
def delete_a_record():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile.index)
    dr=int(input('enter record index of the record to be deleted: '))
    mobile.drop(dr, axis=0, inplace=True)
    mobile.to_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv',index=False)
def ascending():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    v=input('enter the column you want to refer for ascending: ')
    print(mobile.sort_values(by=v))
def descending():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile.columns)
    v=input('enter the column you want to refer for descending: ')
    print(mobile.sort_values(by=v, ascending=False))
def sort_data():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile)
    while True:
        n=int(input('Enter 1 to sort price\n Enter 2 to sort ratings\n Enter 3 to sort camera megapixel\n Enter 4 to sort display size\n Enter 5 to sort storage\n Enter 6 to sort ram\n Enter 7 to sort battery power\n enter 8 when you aredone with the filter\n'))
        if n==1:
            print('filtered by Price')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_price=mobile.sort_values(by='PRICE')
                print('sorted by Price: low to high')
                print(sorted_data_by_price)
            elif l==2:
                sorted_data_by_price=mobile.sort_values(by='PRICE', ascending=False)
                print('sorted by Price: high to low')
                print(sorted_data_by_price)
        elif n==2:
            print('filtered by Ratings')
            l=int(input("1.  high to low\n 2. low to high\n "))
            if l==1:
                sorted_data_by_ratings=mobile.sort_values(by='RATINGS', ascending=False)
                print('sorted by ratings: high to low')
                print(sorted_data_by_ratings)
            elif l==2:
                sorted_data_by_ratings=mobile.sort_values(by='RATINGS')
                print('sorted by ratings: low to high')
                print(sorted_data_by_ratings)
        elif n==3:
            print('filtered by Camera Quality')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_camera=mobile.sort_values(by='CAMERA')
                print('sorted by Camera: low to high')
                print(sorted_data_by_camera)
            elif l==2:
                sorted_data_by_camera=mobile.sort_values(by='CAMERA', ascending=False)
                print('sorted by Camera: high to low')
                print(sorted_data_by_camera)
        elif n==4:
            print('filtered by Display Size')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_size=mobile.sort_values(by='DISPLAY SIZE')
                print('sorted by Display size: low to high')
                print(sorted_data_by_size)
            elif l==2:
                sorted_data_by_size=mobile.sort_values(by='DISPLAY SIZE', ascending=False)
                print('sorted by Display size: high to low')
                print(sorted_data_by_size)
        elif n==5:
            print('filtered by Storage')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_storage=mobile.sort_values(by='STORAGE')
                print('sorted by Storage: low to high')
                print(sorted_data_by_storage)
            elif l==2:
                sorted_data_by_storage=mobile.sort_values(by='STORAGE', ascending=False)
                print('sorted by Storage: high to low')
                print(sorted_data_by_storage)
        elif n==6:
            print('filtered by ram')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_ram=mobile.sort_values(by='RAM')
                print('sorted by RAM: low to high')
                print(sorted_data_by_ram)
            elif l==2:
                sorted_data_by_ram=mobile.sort_values(by='RAM', ascending=False)
                print('sorted by RAM: high to low')
                print(sorted_data_by_ram)
        elif n==7:
            print('filtered by battery')
            l=int(input("1. low to high\n 2. high to low\n "))
            if l==1:
                sorted_data_by_battery=mobile.sort_values(by='BATTERY')
                print('sorted by battery power: low to high')
                print(sorted_data_by_battery)
            elif l==2:
                sorted_data_by_battery=mobile.sort_values(by='BATTERY', ascending=False)
                print('sorted by battery power: high to low')
                print(sorted_data_by_battery)
        else:
            break
def filter_by_features():
    mobile=pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
    print(mobile)
    print('FILTER BY FEATURES')
    while True:
        a=int(input("1. brand mp\n 2. model\n 3. review\n 4. camera mp\n 5. display\n 6. display size\n 7. storage\n 8. ram\n 9. os\n 10. battery power\n 11. done\n"))
        if a==1:
            filtered_brand=input('enter brand to filter: 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print(filtered_data)
            else:
                print('Sorry. This brand is not available at this moment')
        elif a==2:
            filtered_model=input('enter model to filter: 1.')
            a=list(mobile['MODEL'])
            if filtered_model in a:
                filtered_data=mobile[mobile['MODEL']==filtered_model]
                print(filtered_data)
            else:
                print('Sorry. This model is not available at this moment')
        elif a==3:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('choose from review: ',filtered_data['REVIEW'])
                b=list(filtered_data['REVIEW'])
                filtered_review=input('enter review to show: ')
                if filtered_review in b:
                    final_filtered_data=filtered_data[filtered_data['REVIEW']==filtered_review]
                    print(final_filtered_data)
                else:
                    print('Sorry. The review panel doesnot include this')
            elif filtered_brand not in a:
                print('choose from review: ',mobile['REVIEW'])
                c=list(mobile['REVIEW'])
                filtered_review=input('enter review to show: ')
                if filtered_review in c:
                    filtered_data=mobile[mobile['REVIEW']==filtered_review]
                    print(filtered_data)
                else:
                    print('Sorry. The review panel doesnot include this')
        elif a==4:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available camera quality(mp) are:', filtered_data['CAMERA'])
                b=list(filtered_data['CAMERA'])
                filtered_camera=int(input('enter camera mp to filter: '))
                if filtered_camera in b:
                    final_filtered_data=filtered_data[filtered_data['CAMERA']==filtered_camera]
                    print(final_filtered_data)
                else:
                    print('Sorry. This quality camera is not available in this brand')
            elif filtered_brand not in a:
                print('available camera quality(mp) are: ',mobile['CAMERA'])
                filtered_camera=int(input('enter camera mp to filter: '))
                c=list(mobile['CAMERA'])
                if filtered_camera in c:
                    filtered_data=mobile[mobile['CAMERA']==filtered_camera]
                    print(filtered_data)
                else:
                    print('Sorry. This quality camera is not available')
        elif a==5:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available display type are:', filtered_data['DISPLAY'])
                filtered_display=input('enter display to filter: ')
                b=list(filtered_data['DISPLAY'])
                if filtered_display in b:
                    final_filtered_data=filtered_data[filtered_data['DISPLAY']==filtered_display]
                    print(final_filtered_data)
                else:
                    print('Sorry. This display type is not available for this brand')
            elif filtered_brand not in a:
                print('available display type are: ',mobile['DISPLAY'])
                filtered_display=input('enter display to filter: ')
                c=list(mobile['DISPLAY'])
                if filtered_display in c:
                    filtered_data=mobile[mobile['DISPLAY']==filtered_display]
                    print(filtered_data)
                else:
                    print('Sorry. This display type is not available')
        elif a==6:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available display_size are:', filtered_data['DISPLAY SIZE'])
                filtered_display_size=float(input('enter display_size to filter: '))
                b=list(filtered_data['DISPLAY SIZE'])
                if filtered_display_size in b:
                    final_filtered_data=filtered_data[filtered_data['DISPLAY SIZE']==filtered_display_size]
                    print(final_filtered_data)
                else:
                    print('Sorry. This display size is not available for this brand')
            elif filtered_brand not in a:
                print('available display_size are: ',mobile['DISPLAY SIZE'])
                filtered_display_size=float(input('enter display_size to filter: '))
                c=list(mobile['DISPLAY SIZE'])
                if filtered_display_size in c:
                    filtered_data=mobile[mobile['DISPLAY SIZE']==filtered_display_size]
                    print(filtered_data)
                else:
                    print('Sorry. This display size is not available')
        elif a==7:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available storage are:', filtered_data['STORAGE'])
                b=list(filtered_data['STORAGE'])
                filtered_storage=float(input('enter storage to filter: '))
                if filtered_storage in b:
                    final_filtered_data=filtered_data[filtered_data['STORAGE']==filtered_storage]
                    print(final_filtered_data)
                else:
                    print('Sorry. This storage is not available for this brand')
            elif filtered_brand not in a:
                print('available storage are: ',mobile['STORAGE'])
                filtered_storage=float(input('enter storage to filter: '))
                c=list(mobile['STORAGE'])
                if filtered_storage in c:
                    filtered_data=mobile[mobile['STORAGE']==filtered_storage]
                    print(filtered_data)
                else:
                    print('Sorry. This storage is not available')
        elif a==8:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available ram are:', filtered_data['RAM'])
                filtered_ram=float(input('enter storage to filter: '))
                b=list(filtered_data['RAM'])
                if filtered_ram in b:
                    final_filtered_data=filtered_data[filtered_data['RAM']==filtered_ram]
                    print(final_filtered_data)
                else:
                    print('Sorry. This ram is not available for this brand')
            elif filtered_brand not in a:
                print('available ram are: ',mobile['RAM'])
                filtered_ram=float(input('enter ram to filter: '))
                c=list(mobile['RAM'])
                if filtered_ram in c:
                    filtered_data=mobile[mobile['RAM']==filtered_ram]
                    print(filtered_data)
                else:
                    print('Sorry. This ram is not available')
        elif a==9:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a:
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available os are:', filtered_data['OS'])
                filtered_os=input('enter os to filter: ')
                b=list(filtered_data['OS'])
                if filtered_os in b:
                    final_filtered_data=filtered_data[filtered_data['OS']==filtered_os]
                    print(final_filtered_data)
                else:
                    print('Sorry. This os is not available for this brand')
            elif filtered_brand not in a:
                print('available os are: ',mobile['OS'])
                filtered_os=input('enter os to filter: ')
                c=list(mobile['OS'])
                if filtered_os in c:
                    filtered_data=mobile[mobile['OS']==filtered_os]
                    print(filtered_data)
                else:
                    print('Sorry. This storage is not available')
        elif a==10:
            filtered_brand=input('enter brand to filter(optional): 1.apple\n2.benq\n3.blackberry\n4.coolpad\n5.dell\n6.eten\n7.fair phone\n8.google\n9.haier\n10.intex\n11.infinix\n12.jolla\n.13.karbonn\n14.kyocera\n15.lava\n16.lenovo\n17.maxwest\n18.motorola\n19.microsoft\n20.nokia\n21.nothing\n22.nvidia\n23.oneplus\n24.oppo\n25.orange\n26.panasonic\n27.phillips\n28.q-mobiles\n29.realme\n30.redmi\n31.samsung\n32.sony\n33.tecno\n34.t-mobile\n35.tcl\n36.ulefone\n37.unnecto\n38.vivo\n39.vodaphone\n40.verykool\n41.wiko\n42.yezz\n43.yu\n44.zte\n')
            a=list(mobile['BRAND'])
            if filtered_brand in a: 
                filtered_data=mobile[mobile['BRAND']==filtered_brand]
                print('available battery power are:', filtered_data['BATTERY'])
                filtered_battery_power=int(input('enter battery power to filter: '))
                b=list(filtered_data['BATTERY'])
                if filtered_battery_power in b:
                    final_filtered_data=filtered_data[filtered_data['BATTERY']==filtered_battery_power]
                    print(final_filtered_data)
                else:
                    print('Sorry. This storage is not available for this brand')
            elif filtered_brand not in a:
                print('available battery power are: ',mobile['BATTERY'])
                filtered_battery_power=int(input('enter battery power to filter: '))
                c=list(mobile['BATTERY'])
                if filtered_battery_power in c:
                    filtered_data=mobile[mobile['BATTERY']==filtered_battery_power]
                    print(filtered_data)
                else:
                    print('Sorry. This battery power is not available')
        else:
            print('okay.Seems like you are done with your filters')
            break
def graphs():
    d=int(input('enter 1 for bar graph\nenter 2 for line graph\n enter 3 for histogram\n'))
    if d==1:
        def brandvsratings():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.bar(mobile_data['BRAND'], mobile_data['RATINGS'], color='peachpuff')
            plt.title('Ratings Comparison')
            plt.xlabel('Mobile Brands')
            plt.ylabel('Ratings')
            plt.xticks(rotation=90)
            plt.show()
        def brandvsprice():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.bar(mobile_data['BRAND'], mobile_data['PRICE'], color='green')
            plt.title('Prices Comparison')
            plt.xlabel('Mobile Brands')
            plt.ylabel('Prices')
            plt.xticks(rotation=90)
            plt.show()
        def brandvsbattery():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.bar(mobile_data['BRAND'], mobile_data['BATTERY'], color='darkkhaki')
            plt.title('Maximum Battery Capacities Comparison')
            plt.xlabel('Mobile Brands')
            plt.ylabel('Max Battery Capacities')
            plt.xticks(rotation=90)
            plt.show()
        def brandvsram():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.bar(mobile_data['BRAND'], mobile_data['RAM'], color='lightcoral')
            plt.title('Max Ram Comparison')
            plt.xlabel('Mobile Brands')
            plt.ylabel('Max Ram')
            plt.xticks(rotation=90)
            plt.show()
        def brandvscamera():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.bar(mobile_data['BRAND'], mobile_data['CAMERA'], color='thistle')
            plt.title('Camera MP Comparison')
            plt.xlabel('Mobile Brands')
            plt.ylabel('Camera mp')
            plt.xticks(rotation=90)  
            plt.show()
        def brandvsrevenue1990():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.bar(mobile_data['BRAND'], mobile_data['ANNUAL REVENUE 1990'], color='powderblue')
            plt.title('Revenue Comparison of 1990')
            plt.xlabel('brand')
            plt.ylabel('annual revenue in million')
            plt.xticks(rotation=90) 
            plt.show()
        def brandvsrevenue2000():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.bar(mobile_data['BRAND'], mobile_data['ANNUAL REVENUE 2000'], color='tomato')
            plt.title('Revenue Comparison of 2000')
            plt.xlabel('brand')
            plt.ylabel('annual revenue in million')
            plt.xticks(rotation=90) 
            plt.show()
        def brandvsrevenue2010():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.bar(mobile_data['BRAND'], mobile_data['ANNUAL REVENUE 2010'], color='darksage')
            plt.title('Revenue Comparison of 2010')
            plt.xlabel('brand')
            plt.ylabel('annual revenue in million')
            plt.xticks(rotation=90) 
            plt.show()
        def brandvsrevenue2020():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.bar(mobile_data['BRAND'], mobile_data['ANNUAL REVENUE 2020'], color='darksage')
            plt.title('Revenue Comparison of 2020')
            plt.xlabel('brand')
            plt.ylabel('annual revenue in million')
            plt.xticks(rotation=90) 
            plt.show() 
        def brandvsrevenue1990_2000():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            x=np.arange(len(mobile_data['SR_NO']))
            plt.bar(x,mobile_data['ANNUAL REVENUE 1990'], width=0.42, color='purple',label='REVENUE 1990')
            plt.bar(x+0.42,mobile_data['ANNUAL REVENUE 2000'], width=0.42, color='red',label='REVENUE 2000')
            plt.legend()
            plt.xticks(x,mobile_data['BRAND'])
            plt.ylabel('annual revenue in millions')
            plt.xlabel('brands')
            plt.xticks(rotation=90)
            plt.show()
        def brandvsrevenue2000_2010():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            x=np.arange(len(mobile_data['SR_NO']))
            plt.bar(x,mobile_data['ANNUAL REVENUE 2000'], width=0.42, color='purple',label='REVENUE 2000')
            plt.bar(x+0.42,mobile_data['ANNUAL REVENUE 2010'], width=0.42, color='red',label='REVENUE 2010')
            plt.legend()
            plt.xticks(x,mobile_data['BRAND'])
            plt.ylabel('annual revenue in millions')
            plt.xlabel('brands')
            plt.xticks(rotation=90)
            plt.show()
        def brandvsrevenue2010_2020():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            x=np.arange(len(mobile_data['SR_NO']))
            plt.bar(x,mobile_data['ANNUAL REVENUE 2010'], width=0.42, color='gainsboro',label='REVENUE 2000')
            plt.bar(x+0.42,mobile_data['ANNUAL REVENUE 2020'], width=0.42, color='honeydew',label='REVENUE 2010')
            plt.legend()
            plt.xticks(x,mobile_data['BRAND'])
            plt.ylabel('annual revenue in millions')
            plt.xlabel('brands')
            plt.xticks(rotation=90)
            plt.show()
        def brandvsrevenue1990_2010():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            x=np.arange(len(mobile_data['SR_NO']))
            plt.bar(x,mobile_data['ANNUAL REVENUE 1990'], width=0.42, color='magenta',label='REVENUE 1990')
            plt.bar(x+0.42,mobile_data['ANNUAL REVENUE 2010 '], width=0.42, color='teal',label='REVENUE 2010')
            plt.legend()
            plt.xticks(x,mobile_data['BRAND'])
            plt.ylabel('annual revenue in millions')
            plt.xlabel('brands')
            plt.xticks(rotation=90)
            plt.show()
        def brandvsrevenue1990_2020():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            x=np.arange(len(mobile_data['SR_NO']))
            plt.bar(x,mobile_data['ANNUAL REVENUE 1990'], width=0.42, color='seashell',label='REVENUE 1990')
            plt.bar(x+0.42,mobile_data['ANNUAL REVENUE 2020'], width=0.42, color='rosybrown',label='REVENUE 2020')
            plt.legend()
            plt.xticks(x,mobile_data['BRAND'])
            plt.ylabel('annual revenue in millions')
            plt.xlabel('brands')
            plt.xticks(rotation=90)
            plt.show()
        def brandvsrevenue2000_2020():
            mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            x=np.arange(len(mobile_data['SR_NO']))
            plt.bar(x,mobile_data['ANNUAL REVENUE 2000'], width=0.42, color='mintcream',label='REVENUE 2000')
            plt.bar(x+0.42,mobile_data['ANNUAL REVENUE 2020'], width=0.42, color='firebrick',label='REVENUE 2020')
            plt.legend()
            plt.xticks(x,mobile_data['BRAND'])
            plt.ylabel('annual revenue in millions')
            plt.xlabel('brands')
            plt.xticks(rotation=90)
            plt.show()
        brandvsratings()
        brandvsprice()
        brandvsbattery()
        brandvsram()
        brandvscamera()
        brandvsrevenue1990()
        brandvsrevenue2000()
        brandvsrevenue2010()
        brandvsrevenue2020()
        brandvsrevenue1990_2000()
        brandvsrevenue1990_2010()
        brandvsrevenue1990_2020()
        brandvsrevenue2000_2010()
        brandvsrevenue2000_2020()
        brandvsrevenue2010_2020()
    elif d==2:
        def brandrevenue():
            mobile=pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.plot(mobile['BRAND'], mobile['ANNUAL REVENUE 1990'], color='blue', label='ANNUAL REVENUE 1990')
            plt.plot(mobile['BRAND'], mobile['ANNUAL REVENUE 2000'], color='green', label='ANNUAL REVENUE 2000')
            plt.plot(mobile['BRAND'], mobile['ANNUAL REVENUE 2010'], color='purple', label='ANNUAL REVENUE 2010')
            plt.plot(mobile['BRAND'], mobile['ANNUAL REVENUE 2020'], color='violet', label='ANNUAL REVENUE 2020')
            plt.title('REVENUE in different years')
            plt.xlabel('Mobile Brands')
            plt.ylabel('Revenue')
            plt.xticks(rotation=90) 
            plt.legend()
            plt.show()
        def brandratings():
            mobile=pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.plot(mobile['BRAND'], mobile['RATINGS'], label='Ratings', color='darkcyan')
            plt.title('Comparison of Ratings')
            plt.xlabel('Mobile Brands')
            plt.ylabel('ratings')
            plt.legend()
            plt.xticks(rotation=90)  
            plt.show()
        def brandbattery():
            mobile=pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
            plt.plot(mobile['BRAND'], mobile['BATTERY'], label='Battery', color='black')
            plt.title('Comparison of Battery')
            plt.xlabel('Mobile Brands')
            plt.ylabel('Battery power')
            plt.legend()
            plt.xticks(rotation=90)  
            plt.show()
        brandrevenue()
        brandratings()
        brandbattery()
    elif d==3:
        def histprice():
            mobile = pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')  
            price_data = mobile['PRICE']
            plt.hist(price_data, bins=20, color='skyblue', edgecolor='black')
            plt.title('Distribution of Prices')
            plt.xlabel('Price')
            plt.ylabel('Frequency')
            plt.grid(True)
            plt.show()
        def histstorage():
            mobile= pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')  
            storage_data = mobile['STORAGE']
            plt.hist(storage_data, bins=20, color='pink', edgecolor='black')
            plt.title('Storage')
            plt.xlabel('storage')
            plt.ylabel('Frequency')
            plt.grid(True)
            plt.show()
        def histratings():
            mobile= pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')  
            ratings_data = mobile['RATINGS']
            plt.hist(ratings_data, bins=20, color='black', edgecolor='black')
            plt.title('Ratings')
            plt.xlabel('ratings')
            plt.ylabel('Frequency')
            plt.grid(True)
            plt.show()
        def histcameramp():
            mobile= pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')  
            camera_data = mobile['CAMERA']
            plt.hist(camera_data, bins=20, color='brown', edgecolor='black')
            plt.title('Camera Quality')
            plt.xlabel('camera mp')
            plt.ylabel('Frequency')
            plt.grid(True)
            plt.show()
        histprice()
        histstorage()
        histratings()
        histcameramp()
nn=int(input('if owner press 1: \nif customer press 2\n'))
while True:
    if nn==1:
        n1=int(input('1. enter data \n2. new record \n3. retrieve one specific data \n4. transpose \n5. renaming column \n6. select a column \n7. select a row \n8. select a part of data \n9. delete a column \n10. display \n11. delete a record \n12. ascending \n13. descending \n'))
        if n1==1:
            enter_data()
        elif n1==2:
            new_record()
        elif n1==3:
            retrieve_one_specific_data()
        elif n1==4:
            transpose()
        elif n1==5:
            renaming_column()
        elif n1==6:
            select_a_column()
        elif n1==7:
            select_a_row()
        elif n1==8:
            select_a_part_of_data()
        elif n1==9:
            delete_a_column()
        elif n1==10:
            display()
        elif n1==11:
            delete_a_record()
        elif n1==12:
            ascending()
        elif n1==13:
            descending()
    elif nn==2:
        while True:
            n2=int(input('1. sort data \n 2. filter by features \n  3. statistics\n'))
            if n2==1:
                sort_data()
            elif n2==2:
                filter_by_features()
            elif n2==3:
                graphs()
# Out:
# if owner press 1:
# if customer press 2
# 2
# 1. sort data
#  2. filter by features
#   3. statistics
# 3
# enter 1 for bar graph
# enter 2 for line graph
#  enter 3 for histogram
# 2
# 1. sort data
#  2. filter by features
#   3. statistics
# 3
# enter 1 for bar graph
# enter 2 for line graph
#  enter 3 for histogram
# 3
