# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
mobile_data = pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
x=np.arange(len(mobile_data['SR_NO']))
plt.bar(x,mobile_data['ANNUAL REVENUE 1990'], width=0.42, color='purple',label='REVENUE 1990')
plt.bar(x+0.42,mobile_data['ANNUAL REVENUE 2000'], width=0.42, color='red',label='REVENUE 2000')
plt.legend()
plt.xticks(x,mobile_data['BRAND'])
plt.ylabel('annual revenue in millions')
plt.xlabel('brands')
plt.xticks(rotation=90)
plt.show()
print(mobile_data)
# Out:
#      SR_NO  BRAND                   MODEL     REVIEW  RATINGS  PRICE  CAMERA  \
# 0        1  apple                iphoneGS       good      4.5  12560       3
# 1        2  apple                iphoneXR  very good      4.5  41699      12
# 2        3  apple               iphone 6+       fair      4.5  18499       8
# 3        4  apple               iphone 11  very good      4.6  40999      12
# 4        5  apple               iphone 12       good      4.6  53999      12
# ..     ...    ...                     ...        ...      ...    ...     ...
# 192    193    zte           axon 50 ultra       good      4.0  69990      64
# 193    194    zte         nubia Z50 ultra       fair      3.4  47290      64
# 194    195    zte               blade V40       good      3.9  15990      48
# 195    196    zte  nubia red magic 8 pro+       good      4.3  61647      50
# 196    197    zte          blade v41 vita       good      4.0  20999      50
#
#     DISPLAY  DISPLAY SIZE  STORAGE   RAM         OS  BATTERY  \
# 0       LCD          3.50     32.0   8.0   ios6.1.3     1400
# 1       LCD          6.06     64.0   3.0        ios     2942
# 2       LCD          4.70     64.0   1.0       ios8     1810
# 3       LCD          6.10     64.0   4.0      iod13     3110
# 4      OLED          6.10     64.0   4.0     ios 14     2815
# ..      ...           ...      ...   ...        ...      ...
# 192  AMOLED          6.67    256.0  12.0  android12     5000
# 193  AMOLED          6.80    256.0   8.0  android13     5000
# 194  AMOLED          6.67    256.0   6.0  android12     6000
# 195  AMOLED          6.80    128.0  12.0  android13     5000
# 196  AMOLED          6.60    128.0   6.0  android12     4500
#
#      ANNUAL REVENUE 1990  ANNUAL REVENUE 2000  ANNUAL REVENUE 2010  \
# 0                 125000               192000                35000
# 1                 125000               192000                35000
# 2                 125000               192000                35000
# 3                 125000               192000                35000
# 4                 125000               192000                35000
# ..                   ...                  ...                  ...
# 192                  200                  123                  152
# 193                  200                  123                  152
# 194                  200                  123                  152
# 195                  200                  123                  152
# 196                  200                  123                  152
#
#      ANNUAL REVENUE 2020
# 0                 378320
# 1                 378320
# 2                 378320
# 3                 378320
# 4                 378320
# ..                   ...
# 192                  111
# 193                  111
# 194                  111
# 195                  111
# 196                  111
#
# [197 rows x 17 columns]

# %%
mobile=pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
plt.plot(mobile['BRAND'], mobile['ANNUAL REVENUE 1990'], color='blue', label='ANNUAL REVENUE 1990')
plt.plot(mobile['BRAND'], mobile['ANNUAL REVENUE 2000'], color='green', label='ANNUAL REVENUE 2000')
plt.plot(mobile['BRAND'], mobile['ANNUAL REVENUE 2010'], color='purple', label='ANNUAL REVENUE 2010')
plt.plot(mobile['BRAND'], mobile['ANNUAL REVENUE 2020'], color='violet', label='ANNUAL REVENUE 2020')
plt.title('REVENUE in different years')
plt.xlabel('Mobile Brands')
plt.ylabel('Revenue')
plt.xticks(rotation=90) 
plt.legend()
plt.show()


import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
brand = df['BRAND']
variables_to_compare = ['PRICE', 'CAMERA', 'DISPLAY SIZE', 'STORAGE', 'RAM', 'BATTERY']
fig, axes = plt.subplots(nrows=len(variables_to_compare), ncols=1, figsize=(10, 8))
for i, variable in enumerate(variables_to_compare):
    ax = axes[i]
    ax.bar(brand, df[variable], color='skyblue', edgecolor='black')
    ax.set_title(f'{variable} Comparison')
    ax.set_ylabel(variable)
    ax.grid(True)
plt.tight_layout()
plt.show()



import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
brand = df['BRAND']
variables_to_compare = ['CAMERA', 'DISPLAY SIZE', 'RAM', 'BATTERY']
subset_df = df[['BRAND'] + variables_to_compare]
subset_df.set_index('BRAND', inplace=True)
ax = subset_df.plot(kind='bar', figsize=(10, 8), color='skyblue', edgecolor='black', grid=True)
plt.ylabel('Values')
plt.title('Comparison of Variables across Models')
plt.show()

mobile= pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
plt.hist(mobile['BRAND'], mobile['ANNUAL REVENUE 1990'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 44
#      41 plt.show()
#      43 mobile= pd.read_csv('C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv')
# ---> 44 plt.hist(mobile['BRAND'], mobile['ANNUAL REVENUE 1990'])
#      45 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2618, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2612 @_copy_docstring_and_deprecators(Axes.hist)
#    2613 def hist(
#    2614         x, bins=None, range=None, density=False, weights=None,
#    2615         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2616         orientation='vertical', rwidth=None, log=False, color=None,
#    2617         label=None, stacked=False, *, data=None, **kwargs):
# -> 2618     return gca().hist(
#    2619         x, bins=bins, range=range, density=density, weights=weights,
#    2620         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2621         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2622         color=color, label=label, stacked=stacked,
#    2623         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6790, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6786 # Loop through datasets
#    6787 for i in range(nx):
#    6788     # this will automatically overwrite bins,
#    6789     # so that each histogram uses the same bins
# -> 6790     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6791     tops.append(m)
#    6792 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File <__array_function__ internals>:180, in histogram(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\histograms.py:793, in histogram(a, bins, range, normed, weights, density)
#     681 r"""
#     682 Compute the histogram of a dataset.
#     683
#    (...)
#     789
#     790 """
#     791 a, weights = _ravel_and_check_weights(a, weights)
# --> 793 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     795 # Histogram is an integer or a float array depending on the weights.
#     796 if weights is None:
#
# File ~\anaconda3\lib\site-packages\numpy\lib\histograms.py:431, in _get_bin_edges(a, bins, range, weights)
#     429     bin_edges = np.asarray(bins)
#     430     if np.any(bin_edges[:-1] > bin_edges[1:]):
# --> 431         raise ValueError(
#     432             '`bins` must increase monotonically, when an array')
#     434 else:
#     435     raise ValueError('`bins` must be 1d, when an array')
#
# ValueError: `bins` must increase monotonically, when an array

# %%
import pandas as pd
import matplotlib.pyplot as plt
mobile=pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
plt.hist(mobile['ANNUAL REVENUE'])
plt.show()
mobile=pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
plt.hist(mobile['ANNUAL REVENUE'], cummulative=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 7
#       5 plt.show()
#       6 mobile=pd.read_csv("C:\\Users\\arpit_72tw24v\\OneDrive\\Documents\\mobile.csv")
# ----> 7 plt.hist(mobile['ANNUAL REVENUE'], cummulative=True)
#       8 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2618, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2612 @_copy_docstring_and_deprecators(Axes.hist)
#    2613 def hist(
#    2614         x, bins=None, range=None, density=False, weights=None,
#    2615         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2616         orientation='vertical', rwidth=None, log=False, color=None,
#    2617         label=None, stacked=False, *, data=None, **kwargs):
# -> 2618     return gca().hist(
#    2619         x, bins=bins, range=range, density=density, weights=weights,
#    2620         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2621         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2622         color=color, label=label, stacked=stacked,
#    2623         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6943, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6941 if patch:
#    6942     p = patch[0]
# -> 6943     p._internal_update(kwargs)
#    6944     if lbl is not None:
#    6945         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'cummulative'

# %%
ort camera megapixel\n Enter 4 to sort display size\n Enter 5 to sort storage\n Enter 6 to sort ram\n Enter 7 to sort battery power\n enter 8 when you are done with the filter\n'))
        if n==1:

# %%
import pandas as pd
import matplotlib.pyplot as plt

def
